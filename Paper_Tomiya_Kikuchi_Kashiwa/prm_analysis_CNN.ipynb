# %%
# 格子サイズの選択
lattice_size = 16
# 隠れ層のユニット数の選択
hidden_size = 3

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
# cudaが使えるか確認
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
prm_data_path = f'data/prm_data_L{lattice_size}_CNN_Nh{hidden_size}.pth'

# %%
class CNN2(nn.Module):
    def __init__(self,output_size):
        super(CNN2, self).__init__()
        
        # 畳み込み層
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=2, stride=2, bias=True)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=2, stride=2, bias=True)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=3, kernel_size=4, stride=4, bias=True)
        
        # 畳み込みの部分
        self.conv = nn.Sequential(
            self.conv1,   
            nn.ReLU(inplace=True),
            self.conv2,   
            nn.ReLU(inplace=True),
            self.conv3,   
            nn.ReLU(inplace=True)
        )
        # 全結合の部分
        self.fc = nn.Sequential(
            nn.Linear(3, output_size, bias=True),
            nn.Softmax(dim=1)
        )
    
    def forward(self, x):
        x = self.conv(x)
        return x

# %%
output_size = 20
model = CNN2(output_size).to(device)

model.load_state_dict(torch.load(prm_data_path), strict=False)
print(model.state_dict())
# Out:
# OrderedDict([('conv1.weight', tensor([[[[ 0.2455, -0.0207],
#           [-0.2421, -0.2731]]],
#
#
#         [[[ 0.2278, -0.2218],
#           [ 0.0184,  0.0168]]],
#
#
#         [[[-0.2884,  0.6181],
#           [-0.2755, -0.4452]]],
#
#
#         [[[ 0.7428,  0.3197],
#           [-0.7066, -0.3095]]],
#
#
#         [[[ 0.3667,  0.0875],
#           [-0.3594,  0.2471]]],
#
#
#         [[[-0.4611, -0.3543],
#           [-0.2498,  0.4425]]],
#
#
#         [[[ 0.1887, -0.4473],
#           [ 0.4754, -0.2013]]],
#
#
#         [[[-0.1879,  0.0198],
#           [ 0.1858,  0.0112]]],
#
#
#         [[[ 0.0176,  0.3401],
#           [-0.5780,  0.2139]]],
#
#
#         [[[-0.3927,  0.3925],
#           [-0.0231, -0.3127]]],
#
#
#         [[[-0.2999, -0.3344],
#           [ 0.6613, -0.0947]]],
#
#
#         [[[ 0.0222,  0.1113],
#           [-0.4483,  0.2855]]],
#
#
#         [[[ 0.9923, -0.8455],
#           [-0.1165, -0.1593]]],
#
#
#         [[[ 0.3378,  0.3204],
#           [-0.2552,  0.2602]]],
#
#
#         [[[-0.0132,  0.1427],
#           [ 0.7141, -0.7674]]],
#
#
#         [[[-0.5584,  0.6066],
#           [ 0.4869, -0.5055]]],
#
#
#         [[[ 0.0807, -0.2581],
#           [-0.1020,  0.3213]]],
#
#
#         [[[ 0.2635,  0.2650],
#           [ 0.2644,  0.2669]]],
#
#
#         [[[ 0.2702, -0.2919],
#           [ 0.2892, -0.2017]]],
#
#
#         [[[-0.3327,  0.3203],
#           [ 0.6966, -0.7913]]],
#
#
#         [[[-0.1595,  0.2857],
#           [-0.0575, -0.0183]]],
#
#
#         [[[ 0.4519,  0.1875],
#           [ 0.4428, -0.6306]]],
#
#
#         [[[-0.2901, -0.1163],
#           [ 0.0676, -0.4157]]],
#
#
#         [[[ 0.1007,  0.3748],
#           [-0.3469,  0.0403]]],
#
#
#         [[[ 0.2412, -0.3026],
#           [ 0.3878, -0.3097]]],
#
#
#         [[[ 0.3424, -0.0129],
#           [-0.0209, -0.4413]]],
#
#
#         [[[-0.1339,  0.1087],
#           [-0.0171,  0.0598]]],
#
#
#         [[[-0.4053,  0.0355],
#           [ 0.2962,  0.1339]]],
#
#
#         [[[ 0.3257,  0.3774],
#           [ 0.2450,  0.1997]]],
#
#
#         [[[ 0.0066,  0.3640],
#           [-0.1146,  0.3020]]],
#
#
#         [[[-0.3509,  0.3532],
#           [ 0.1446,  0.0072]]],
#
#
#         [[[ 0.0157,  0.1011],
#           [-0.4126, -0.3261]]],
#
#
#         [[[ 0.3130,  0.2987],
#           [ 0.0538, -0.6029]]],
#
#
#         [[[-0.3779, -0.1710],
#           [ 0.2563,  0.4386]]],
#
#
#         [[[-0.5518,  0.2088],
#           [ 0.1733,  0.3613]]],
#
#
#         [[[ 0.1164,  0.3981],
#           [-0.3969, -0.3957]]],
#
#
#         [[[-0.2735, -0.1152],
#           [ 0.4216, -0.2948]]],
#
#
#         [[[-0.3708, -0.4010],
#           [ 0.5243,  0.2101]]],
#
#
#         [[[-0.5337,  0.4114],
#           [-0.6460,  0.7515]]],
#
#
#         [[[ 0.3048, -0.1651],
#           [ 0.3673, -0.5506]]],
#
#
#         [[[ 0.3390,  0.4665],
#           [-0.4457, -0.4101]]],
#
#
#         [[[-0.1832, -0.0363],
#           [ 0.2490, -0.0347]]],
#
#
#         [[[-0.3640, -0.0963],
#           [ 0.4822, -0.1122]]],
#
#
#         [[[ 0.2926,  0.0098],
#           [ 0.1301,  0.4168]]],
#
#
#         [[[-0.4285,  0.2667],
#           [ 0.3149,  0.1601]]],
#
#
#         [[[ 0.4177, -0.3763],
#           [ 0.0546,  0.0024]]],
#
#
#         [[[-0.1846,  0.3212],
#           [-0.2297,  0.0910]]],
#
#
#         [[[ 0.2685, -0.2884],
#           [-0.2211,  0.2055]]],
#
#
#         [[[ 0.3339,  0.2942],
#           [-0.3221, -0.2878]]],
#
#
#         [[[-0.2912,  0.4314],
#           [-0.4871,  0.3507]]],
#
#
#         [[[ 0.0227, -0.5083],
#           [ 0.2924,  0.2069]]],
#
#
#         [[[ 0.5020, -0.2049],
#           [-0.2385, -0.1543]]],
#
#
#         [[[-0.2117,  0.0912],
#           [ 0.2503,  0.0140]]],
#
#
#         [[[-0.1911,  0.2152],
#           [ 0.3691, -0.3745]]],
#
#
#         [[[ 0.2469,  0.4975],
#           [-0.2938, -0.3112]]],
#
#
#         [[[ 0.1256, -0.2704],
#           [ 0.1717,  0.1872]]],
#
#
#         [[[ 0.4021, -0.4903],
#           [-0.0092,  0.1190]]],
#
#
#         [[[ 0.4759,  0.4737],
#           [ 0.4707,  0.1423]]],
#
#
#         [[[ 0.3066,  0.2773],
#           [-0.0399,  0.2661]]],
#
#
#         [[[ 0.3543, -0.0395],
#           [-0.5672,  0.2947]]],
#
#
#         [[[-0.0717, -0.3822],
#           [-0.2089,  0.5621]]],
#
#
#         [[[-0.2054, -0.6662],
#           [ 0.1887,  0.7350]]],
#
#
#         [[[-0.2262, -0.3246],
#           [-0.0120, -0.0422]]],
#
#
#         [[[-0.2454,  0.0890],
#           [-0.2081,  0.3344]]]])), ('conv1.bias', tensor([ 0.1759, -0.0640, -0.2060, -0.0695, -0.3668, -0.1470, -0.0792, -0.0965,
#         -0.1015,  0.1354, -0.1739, -0.0864, -0.1717, -0.5017, -0.2157, -0.1810,
#         -0.0594, -0.0084,  0.0356, -0.1632,  0.0212, -0.4765,  0.2432,  0.0463,
#         -0.0693,  0.0625, -0.1064, -0.0869,  0.2209,  0.0073,  0.0378, -0.0041,
#         -0.0245, -0.3256, -0.2444, -0.5412, -0.3444,  0.0532, -0.0381, -0.0994,
#         -0.2123, -0.1692, -0.1601, -0.4391, -0.3450,  0.0772, -0.0810, -0.0243,
#         -0.0622, -0.1078, -0.0641, -0.1251, -0.0793, -0.0452, -0.2771, -0.0791,
#         -0.0676,  0.3234, -0.0111, -0.1297, -0.1465, -0.0688,  0.0160,  0.1589])), ('conv2.weight', tensor([[[[-1.3335e-02,  2.1268e-02],
#           [ 6.8019e-02,  2.4323e-02]],
#
#          [[ 1.2863e-02,  5.6937e-02],
#           [ 2.8465e-02, -2.9322e-02]],
#
#          [[ 3.8672e-02,  2.0105e-03],
#           [ 1.5710e-02, -7.8105e-02]],
#
#          ...,
#
#          [[-9.4083e-02,  9.4018e-02],
#           [ 2.8087e-01, -8.0299e-02]],
#
#          [[ 2.2551e-02,  1.5604e-02],
#           [ 3.8610e-03, -5.9001e-02]],
#
#          [[-1.5755e-02, -7.8709e-02],
#           [ 4.7780e-02, -2.8357e-03]]],
#
#
#         [[[ 1.5732e-02,  1.0731e-01],
#           [-5.9723e-02, -6.7339e-02]],
#
#          [[ 4.4448e-03,  2.9857e-02],
#           [ 1.2923e-02,  1.8528e-02]],
#
#          [[-2.9895e-03,  6.8821e-02],
#           [-7.1754e-03,  2.0951e-02]],
#
#          ...,
#
#          [[ 3.4474e-01,  4.9839e-01],
#           [ 4.1837e-01,  6.4638e-01]],
#
#          [[-8.0728e-02, -4.1402e-03],
#           [-4.7688e-02,  8.2415e-03]],
#
#          [[-1.3537e-02,  9.1156e-02],
#           [ 2.5888e-02, -3.4985e-02]]],
#
#
#         [[[ 7.7539e-02,  7.0581e-02],
#           [-4.1932e-02, -2.4192e-02]],
#
#          [[ 3.3805e-03,  3.6691e-02],
#           [ 9.4020e-02,  6.1703e-02]],
#
#          [[ 2.6943e-02, -1.5147e-02],
#           [ 4.5610e-02, -3.4127e-02]],
#
#          ...,
#
#          [[-1.0788e-01,  3.6476e-01],
#           [ 3.8821e-02,  1.3624e-02]],
#
#          [[ 1.8942e-02,  2.9479e-02],
#           [ 9.1469e-03,  7.3448e-02]],
#
#          [[-8.1211e-02,  1.2732e-02],
#           [-4.1473e-02, -7.4871e-02]]],
#
#
#         ...,
#
#
#         [[[-1.5225e-02, -4.3896e-02],
#           [ 4.2454e-04, -4.8017e-02]],
#
#          [[ 2.3752e-02,  3.2550e-02],
#           [-7.6270e-02, -2.5201e-02]],
#
#          [[ 2.1542e-02, -1.7655e-02],
#           [-1.5106e-03, -1.7493e-02]],
#
#          ...,
#
#          [[ 1.5216e-02, -3.4364e-02],
#           [ 4.4093e-02,  2.1693e-02]],
#
#          [[-7.2119e-02, -7.5129e-02],
#           [-5.4816e-02,  6.3422e-03]],
#           [ 7.2311e-02, -7.7765e-02,  7.5061e-02,  5.3102e-02]],
#
#          [[ 1.8576e-01,  4.5207e-01,  3.1077e-01,  2.2510e-01],
#           [ 2.8192e-01,  1.2947e-01,  9.1157e-02,  3.3093e-01],
#           [ 3.3054e-01,  1.4994e-01,  3.4693e-01,  2.0143e-01],
#           [ 2.8887e-01,  1.7615e-01,  2.0859e-01,  1.4995e-01]],
#
#          [[-1.3281e-01,  1.2291e-01,  4.2970e-02,  1.1762e-02],
#           [-2.6119e-04,  1.3373e-01,  3.4938e-02,  1.2630e-03],
#           [-6.1747e-04,  3.0532e-02,  2.2147e-02,  8.8974e-02],
#           [ 5.4103e-02, -3.1247e-02, -4.1701e-03,  1.8043e-01]],
#
#          ...,
#
#          [[ 7.5500e-03, -8.6602e-03, -1.4961e-02, -4.2776e-04],
#           [ 4.2842e-02, -3.4448e-02, -4.0934e-02, -1.4282e-02],
#           [-2.9938e-03, -1.8613e-02, -1.8750e-02,  5.3776e-03],
#           [ 1.7550e-02, -4.4473e-03,  3.9252e-02,  2.1281e-02]],
#
#          [[-4.1021e-02,  1.1054e-02,  6.6155e-02,  4.0318e-02],
#           [ 1.9369e-02, -7.4966e-02,  8.6808e-03, -1.8819e-02],
#           [-1.2594e-02, -3.8825e-02,  1.2098e-01, -2.2842e-02],
#           [-6.6477e-03,  8.9781e-02,  1.9342e-04, -1.9104e-02]],
#
#          [[ 4.0494e-01,  4.5755e-01,  4.9063e-01,  3.6275e-01],
#           [ 4.6868e-01,  5.3777e-01,  5.3811e-01,  4.8622e-01],
#           [ 3.3064e-01,  4.0524e-01,  3.5196e-01,  4.5746e-01],
#           [ 3.8166e-01,  4.5022e-01,  5.2825e-01,  3.8652e-01]]]])), ('conv3.bias', tensor([-0.0115,  0.1632,  0.1257])), ('conv.0.weight', tensor([[[[ 0.2455, -0.0207],
#           [-0.2421, -0.2731]]],
#
#
#         [[[ 0.2278, -0.2218],
#           [ 0.0184,  0.0168]]],
#
#
#         [[[-0.2884,  0.6181],
#           [-0.2755, -0.4452]]],
#
#
#         [[[ 0.7428,  0.3197],
#           [-0.7066, -0.3095]]],
#
#
#         [[[ 0.3667,  0.0875],
#           [-0.3594,  0.2471]]],
#
#
#         [[[-0.4611, -0.3543],
#           [-0.2498,  0.4425]]],
#
#
#         [[[ 0.1887, -0.4473],
#           [ 0.4754, -0.2013]]],
#
#
#         [[[-0.1879,  0.0198],
#           [ 0.1858,  0.0112]]],
#
#
#         [[[ 0.0176,  0.3401],
#           [-0.5780,  0.2139]]],
#
#
#         [[[-0.3927,  0.3925],
#           [-0.0231, -0.3127]]],
#
#
#         [[[-0.2999, -0.3344],
#           [ 0.6613, -0.0947]]],
#
#
#         [[[ 0.0222,  0.1113],
#           [-0.4483,  0.2855]]],
#
#
#         [[[ 0.9923, -0.8455],
#           [-0.1165, -0.1593]]],
#
#
#         [[[ 0.3378,  0.3204],
#           [-0.2552,  0.2602]]],
#
#
#         [[[-0.0132,  0.1427],
#           [ 0.7141, -0.7674]]],
#
#
#         [[[-0.5584,  0.6066],
#           [ 0.4869, -0.5055]]],
#
#
#         [[[ 0.0807, -0.2581],
#           [-0.1020,  0.3213]]],
#
#
#         [[[ 0.2635,  0.2650],
#           [ 0.2644,  0.2669]]],
#
#
#         [[[ 0.2702, -0.2919],
#           [ 0.2892, -0.2017]]],
#
#
#         [[[-0.3327,  0.3203],
#           [ 0.6966, -0.7913]]],
#
#
#         [[[-0.1595,  0.2857],
#           [-0.0575, -0.0183]]],
#
#
#         [[[ 0.4519,  0.1875],
#           [ 0.4428, -0.6306]]],
#
#
#         [[[-0.2901, -0.1163],
#           [ 0.0676, -0.4157]]],
#
#
#         [[[ 0.1007,  0.3748],
#           [-0.3469,  0.0403]]],
#
#
#         [[[ 0.2412, -0.3026],
#           [ 0.3878, -0.3097]]],
#
#
#         [[[ 0.3424, -0.0129],
#           [-0.0209, -0.4413]]],
#
#
#         [[[-0.1339,  0.1087],
#           [-0.0171,  0.0598]]],
#
#
#         [[[-0.4053,  0.0355],
#           [ 0.2962,  0.1339]]],
#
#
#         [[[ 0.3257,  0.3774],
#           [ 0.2450,  0.1997]]],
#
#
#         [[[ 0.0066,  0.3640],
#           [-0.1146,  0.3020]]],
#
#
#         [[[-0.3509,  0.3532],
#           [ 0.1446,  0.0072]]],
#
#
#         [[[ 0.0157,  0.1011],
#           [-0.4126, -0.3261]]],
#
#
#         [[[ 0.3130,  0.2987],
#           [ 0.0538, -0.6029]]],
#
#
#         [[[-0.3779, -0.1710],
#           [ 0.2563,  0.4386]]],
#
#
#         [[[-0.5518,  0.2088],
#           [ 0.1733,  0.3613]]],
#
#
#         [[[ 0.1164,  0.3981],
#           [-0.3969, -0.3957]]],
#
#
#         [[[-0.2735, -0.1152],
#           [ 0.4216, -0.2948]]],
#
#
#         [[[-0.3708, -0.4010],
#           [ 0.5243,  0.2101]]],
#
#
#         [[[-0.5337,  0.4114],
#           [-0.6460,  0.7515]]],
#
#
#         [[[ 0.3048, -0.1651],
#           [ 0.3673, -0.5506]]],
#
#
#         [[[ 0.3390,  0.4665],
#           [-0.4457, -0.4101]]],
#
#
#         [[[-0.1832, -0.0363],
#           [ 0.2490, -0.0347]]],
#
#
#         [[[-0.3640, -0.0963],
#           [ 0.4822, -0.1122]]],
#
#
#         [[[ 0.2926,  0.0098],
#           [ 0.1301,  0.4168]]],
#
#
#         [[[-0.4285,  0.2667],
#           [ 0.3149,  0.1601]]],
#
#
#         [[[ 0.4177, -0.3763],
#           [ 0.0546,  0.0024]]],
#
#
#         [[[-0.1846,  0.3212],
#           [-0.2297,  0.0910]]],
#
#
#         [[[ 0.2685, -0.2884],
#           [-0.2211,  0.2055]]],
#
#
#         [[[ 0.3339,  0.2942],
#           [-0.3221, -0.2878]]],
#
#
#         [[[-0.2912,  0.4314],
#           [-0.4871,  0.3507]]],
#
#
#         [[[ 0.0227, -0.5083],
#           [ 0.2924,  0.2069]]],
#
#
#         [[[ 0.5020, -0.2049],
#           [-0.2385, -0.1543]]],
#
#
#         [[[-0.2117,  0.0912],
#           [ 0.2503,  0.0140]]],
#
#
#         [[[-0.1911,  0.2152],
#           [ 0.3691, -0.3745]]],
#
#
#         [[[ 0.2469,  0.4975],
#           [-0.2938, -0.3112]]],
#
#
#         [[[ 0.1256, -0.2704],
#           [ 0.1717,  0.1872]]],
#
#
#         [[[ 0.4021, -0.4903],
#           [-0.0092,  0.1190]]],
#
#
#         [[[ 0.4759,  0.4737],
#           [ 0.4707,  0.1423]]],
#
#
#         [[[ 0.3066,  0.2773],
#           [-0.0399,  0.2661]]],
#
#
#         [[[ 0.3543, -0.0395],
#           [-0.5672,  0.2947]]],
#
#
#         [[[-0.0717, -0.3822],
#           [-0.2089,  0.5621]]],
#
#
#         [[[-0.2054, -0.6662],
#           [ 0.1887,  0.7350]]],
#
#
#         [[[-0.2262, -0.3246],
#           [-0.0120, -0.0422]]],
#
#
#         [[[-0.2454,  0.0890],
#           [-0.2081,  0.3344]]]])), ('conv.0.bias', tensor([ 0.1759, -0.0640, -0.2060, -0.0695, -0.3668, -0.1470, -0.0792, -0.0965,
#         -0.1015,  0.1354, -0.1739, -0.0864, -0.1717, -0.5017, -0.2157, -0.1810,
#         -0.0594, -0.0084,  0.0356, -0.1632,  0.0212, -0.4765,  0.2432,  0.0463,
#         -0.0693,  0.0625, -0.1064, -0.0869,  0.2209,  0.0073,  0.0378, -0.0041,
#         -0.0245, -0.3256, -0.2444, -0.5412, -0.3444,  0.0532, -0.0381, -0.0994,
#         -0.2123, -0.1692, -0.1601, -0.4391, -0.3450,  0.0772, -0.0810, -0.0243,
#         -0.0622, -0.1078, -0.0641, -0.1251, -0.0793, -0.0452, -0.2771, -0.0791,
#         -0.0676,  0.3234, -0.0111, -0.1297, -0.1465, -0.0688,  0.0160,  0.1589])), ('conv.2.weight', tensor([[[[-1.3335e-02,  2.1268e-02],
#           [ 6.8019e-02,  2.4323e-02]],
#
#          [[ 1.2863e-02,  5.6937e-02],
#           [ 2.8465e-02, -2.9322e-02]],
#
#          [[ 3.8672e-02,  2.0105e-03],
#           [ 1.5710e-02, -7.8105e-02]],
#
#          ...,
#
#          [[-9.4083e-02,  9.4018e-02],
#           [ 2.8087e-01, -8.0299e-02]],
#
#          [[ 2.2551e-02,  1.5604e-02],
#           [ 3.8610e-03, -5.9001e-02]],
#
#          [[-1.5755e-02, -7.8709e-02],
#           [ 4.7780e-02, -2.8357e-03]]],
#
#
#         [[[ 1.5732e-02,  1.0731e-01],
#           [-5.9723e-02, -6.7339e-02]],
#
#          [[ 4.4448e-03,  2.9857e-02],
#           [ 1.2923e-02,  1.8528e-02]],
#
#          [[-2.9895e-03,  6.8821e-02],
#           [-7.1754e-03,  2.0951e-02]],
#
#          ...,
#
#          [[ 3.4474e-01,  4.9839e-01],
#           [ 4.1837e-01,  6.4638e-01]],
#
#          [[-8.0728e-02, -4.1402e-03],
#           [-4.7688e-02,  8.2415e-03]],
#
#          [[-1.3537e-02,  9.1156e-02],
#           [ 2.5888e-02, -3.4985e-02]]],
#
#
#         [[[ 7.7539e-02,  7.0581e-02],
#           [-4.1932e-02, -2.4192e-02]],
#
#          [[ 3.3805e-03,  3.6691e-02],
#           [ 9.4020e-02,  6.1703e-02]],
#
#          [[ 2.6943e-02, -1.5147e-02],
#           [ 4.5610e-02, -3.4127e-02]],
#
#          ...,
#
#          [[-1.0788e-01,  3.6476e-01],
#           [ 3.8821e-02,  1.3624e-02]],
#
#          [[ 1.8942e-02,  2.9479e-02],
#           [ 9.1469e-03,  7.3448e-02]],
#
#          [[-8.1211e-02,  1.2732e-02],
#           [-4.1473e-02, -7.4871e-02]]],
#
#
#         ...,
#
#
#         [[[-1.5225e-02, -4.3896e-02],
#           [ 4.2454e-04, -4.8017e-02]],
#
#          [[ 2.3752e-02,  3.2550e-02],
#           [-7.6270e-02, -2.5201e-02]],
#
#          [[ 2.1542e-02, -1.7655e-02],
#           [-1.5106e-03, -1.7493e-02]],
#
#          ...,
#
#          [[ 1.5216e-02, -3.4364e-02],
#           [ 4.4093e-02,  2.1693e-02]],
#
#          [[-7.2119e-02, -7.5129e-02],
#           [-5.4816e-02,  6.3422e-03]],
#
#          [[-9.4471e-02, -4.1658e-02],
#           [-1.6214e-02, -8.0849e-02]]],
#
#
#         [[[ 1.1329e-01,  1.0173e-01],
#           [-7.0740e-02, -8.1883e-02]],
#
#          [[-1.8371e-01, -4.9371e-01],
#           [ 8.3525e-02, -1.6022e-01]],
#
#          [[ 6.1727e-02, -3.9221e-04],
#           [-4.6916e-02, -8.8879e-02]],
#
#          ...,
#
#          [[ 2.2514e-02, -1.4960e-01],
#           [ 1.6166e-01, -1.5503e-02]],
#
#          [[ 1.7174e-01,  7.2839e-02],
#           [-2.3318e-02,  6.4555e-03]],
#
#          [[-3.3725e-02,  1.9202e-01],
#           [ 4.3118e-02,  5.8065e-02]]],
#
#
#         [[[ 1.2437e-02,  4.3821e-02],
#           [ 1.3600e-02,  3.2897e-02]],
#
#          [[ 3.9170e-02,  9.7479e-02],
#           [ 2.7086e-02, -3.7443e-02]],
#
#          [[-9.8165e-03,  1.5750e-01],
#           [ 2.8291e-02,  1.0517e-01]],
#
#          ...,
#
#          [[ 4.5792e-01,  7.0781e-01],
#           [ 4.9166e-01,  4.8255e-01]],
#
#          [[-5.2017e-02, -1.6232e-01],
#           [-9.9203e-02,  1.5804e-02]],
#
#          [[-5.1535e-02, -1.1484e-02],
#           [-9.8875e-03,  3.7528e-02]]]])), ('conv.2.bias', tensor([ 3.1915e-02,  1.3580e-02, -3.8350e-02, -4.2256e-02,  7.8638e-02,
#          4.4497e-02, -4.6510e-03, -2.0543e-02,  2.2307e-02,  5.9316e-02,
#         -9.0497e-03, -1.5554e-02, -7.8641e-02,  1.9404e-02,  1.2755e-01,
#          3.4640e-02,  7.4304e-02, -3.5147e-02, -4.1489e-02, -6.9193e-02,
#          7.7969e-02, -2.4788e-02,  1.2012e-01, -9.5783e-05,  5.8196e-02,
#          5.3096e-02, -7.2008e-02, -1.2484e-01, -8.1015e-02, -6.5240e-03,
#          5.5865e-02, -3.6147e-02])), ('conv.4.weight', tensor([[[[-1.6670e-02, -4.4597e-02, -9.5608e-03, -5.6378e-03],
#           [ 6.1439e-03, -9.0446e-03,  1.4501e-02, -3.5189e-03],
#           [-3.6077e-02, -3.1642e-02, -7.8836e-03, -3.2667e-02],
#           [-3.3396e-02, -2.2616e-02, -4.3942e-02, -1.7305e-02]],
#           [ 2.2240e-01,  1.1973e-01,  2.1075e-01,  2.4913e-01],
#           [ 1.8431e-01,  3.5908e-01,  2.4932e-01,  2.4945e-01],
#           [ 3.3291e-01,  2.7891e-01,  3.7522e-01,  2.4567e-01]],
#
#          [[ 3.7446e-03, -8.2536e-02, -3.3733e-02,  2.8104e-03],
#           [-4.6002e-02, -9.9905e-03,  1.0061e-02, -1.7885e-02],
#           [ 1.0065e-02, -5.1864e-02, -4.4517e-02,  7.3667e-03],
#           [-3.1327e-02, -6.4944e-02, -8.2689e-02, -2.9596e-02]]],
#
#
#         [[[ 6.7216e-02,  6.9941e-02, -1.5890e-03,  3.2999e-02],
#           [ 3.6146e-02,  1.5341e-01,  5.0308e-02,  7.6520e-03],
#           [ 4.8213e-02,  1.3566e-01,  6.5391e-02, -5.5342e-02],
#           [ 7.2311e-02, -7.7765e-02,  7.5061e-02,  5.3102e-02]],
#
#          [[ 1.8576e-01,  4.5207e-01,  3.1077e-01,  2.2510e-01],
#           [ 2.8192e-01,  1.2947e-01,  9.1157e-02,  3.3093e-01],
#           [ 3.3054e-01,  1.4994e-01,  3.4693e-01,  2.0143e-01],
#           [ 2.8887e-01,  1.7615e-01,  2.0859e-01,  1.4995e-01]],
#
#          [[-1.3281e-01,  1.2291e-01,  4.2970e-02,  1.1762e-02],
#           [-2.6119e-04,  1.3373e-01,  3.4938e-02,  1.2630e-03],
#           [-6.1747e-04,  3.0532e-02,  2.2147e-02,  8.8974e-02],
#           [ 5.4103e-02, -3.1247e-02, -4.1701e-03,  1.8043e-01]],
#
#          ...,
#
#          [[ 7.5500e-03, -8.6602e-03, -1.4961e-02, -4.2776e-04],
#           [ 4.2842e-02, -3.4448e-02, -4.0934e-02, -1.4282e-02],
#           [-2.9938e-03, -1.8613e-02, -1.8750e-02,  5.3776e-03],
#           [ 1.7550e-02, -4.4473e-03,  3.9252e-02,  2.1281e-02]],
#
#          [[-4.1021e-02,  1.1054e-02,  6.6155e-02,  4.0318e-02],
#           [ 1.9369e-02, -7.4966e-02,  8.6808e-03, -1.8819e-02],
#           [-1.2594e-02, -3.8825e-02,  1.2098e-01, -2.2842e-02],
#           [-6.6477e-03,  8.9781e-02,  1.9342e-04, -1.9104e-02]],
#
#          [[ 4.0494e-01,  4.5755e-01,  4.9063e-01,  3.6275e-01],
#           [ 4.6868e-01,  5.3777e-01,  5.3811e-01,  4.8622e-01],
#           [ 3.3064e-01,  4.0524e-01,  3.5196e-01,  4.5746e-01],
#           [ 3.8166e-01,  4.5022e-01,  5.2825e-01,  3.8652e-01]]]])), ('conv.4.bias', tensor([-0.0115,  0.1632,  0.1257])), ('fc.0.weight', tensor([[-0.5036, -1.5099,  0.4305],
#         [ 0.1129, -1.2294,  0.4192],
#         [-0.0550, -0.9692,  0.4071],
#         [ 0.4868, -0.7469,  0.3834],
#         [-0.1124, -0.5032,  0.3510],
#         [ 0.0646, -0.2767,  0.3133],
#         [ 0.0924, -0.0873,  0.2596],
#         [ 0.4730,  0.0805,  0.1974],
#         [-0.0133,  0.2320,  0.0971],
#         [-0.2677,  0.2951, -0.0265],
#         [-0.0559,  0.3159, -0.1540],
#         [-0.0924,  0.3526, -0.2911],
#         [ 0.2743,  0.3540, -0.4657],
#         [ 0.4347,  0.3586, -0.6130],
#         [ 0.3024,  0.3811, -0.7919],
#         [-0.2693,  0.3880, -0.9790],
#         [-0.4844,  0.3794, -1.1470],
#         [ 0.0696,  0.3979, -1.3242],
#         [ 0.1098,  0.3936, -1.5416],
#         [ 0.3857,  0.3873, -1.7905]])), ('fc.0.bias', tensor([-0.5594, -0.3588, -0.4128,  0.3328,  0.1416,  0.1864,  0.5647,  0.3218,
#         -0.4287, -0.2400,  0.4417, -0.2787,  0.4337,  0.4258, -0.2047, -0.1061,
#          0.7412, -0.3551,  0.0802,  0.0837]))])

# %%
fc_weight = model.state_dict()['fc.0.weight']
# NumPy配列に変換
fc_weight_np = fc_weight.cpu().numpy()
# データを転置して
fc_weight_np_square = fc_weight_np.T

# %%
# ヒートマップをプロット（白黒）
plt.figure(figsize=(6, 6))
plt.imshow(fc_weight_np_square, cmap='gray', interpolation='nearest', origin='lower', aspect='auto')
plt.colorbar()
# plt.title('Heatmap (L16 CNN Nh3)')


# x軸とy軸に名前を付ける
plt.ylabel('weight')
plt.xlabel('label number')
# 図をファイルとして保存
plt.savefig(f'image/L{lattice_size}_CNN_Nh{hidden_size}_wight.png')
plt.show()

# %%
fc_weight_np_square_sum = np.sum(fc_weight_np_square, axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# データ
x = np.arange(len(fc_weight_np_square[1]))
y0 = fc_weight_np_square[0]
y1 = fc_weight_np_square[1]
y2 = fc_weight_np_square[2]

# プロット
plt.figure(figsize=(8, 6))
plt.scatter(x, y0, color='blue', label='a=0')
plt.scatter(x, y1, color='orange', label='a=1')
plt.scatter(x, y2, color='green', label='a=2')
plt.plot(x, y0, color='blue')
plt.plot(x, y1, color='orange')
plt.plot(x, y2, color='green')
# plt.title('$W_{sum}$ plot (L16 CNN Nh3)')
plt.xlabel('label number')
plt.ylabel('$W_{sum}$')
plt.legend()  # 凡例を表示

# 図をファイルとして保存
plt.savefig(f'image/L{lattice_size}_CNN_Nh{hidden_size}_wight_plot.png')
plt.show()

# %% [markdown]
# 第1層の出力と磁化の相関図を作成

# %%
# 磁化を計算
def magnetization(state):
   return np.mean(state)

# %%
import io
import pickle
      
class CPU_Unpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == 'torch.storage' and name == '_load_from_bytes':
            return lambda b: torch.load(io.BytesIO(b), map_location='cpu')
        else: return super().find_class(module, name)
        
# ファイルの相対パスを指定
file_path = f'data/Ising_data_L{lattice_size}_v3.pkl'

if torch.cuda.is_available():
    with open(file_path, 'rb') as file:
        loaded_data = pickle.load(file)
else:
    with open(file_path, 'rb') as file:
        loaded_data = CPU_Unpickler(file).load()
        
# 読み込んだデータを個々の変数に分割
spin_data, label_data = loaded_data

# %%
# NumPy ndarrayをPyTorch Tensorに変換
spin_data_tensor = [torch.from_numpy(i).unsqueeze(0).type(torch.float32) for i in spin_data]
spin_data_tensor[0].size()
# Out:
# torch.Size([1, 16, 16])

# %%
# model.to(device)

# 出力を取得する前に、テンソルを同じデバイスに移動
output = [np.squeeze(model(spin_data_tensor[i]).detach().cpu().numpy()) for i in range(len(spin_data_tensor))]

# %%
# モデルをcuda:0デバイスに移動
# model.to(device)

# spin_data_tensor[1]をcuda:0デバイスに移動
spin_data_tensor_1_cuda = spin_data_tensor[1]

# モデルに入力して出力を取得
a = torch.squeeze(model(spin_data_tensor_1_cuda))

# 出力をnumpyに変換
b = [a[i].detach().cpu().numpy() for i in range(3)]

# %%
num_spin_data = len(spin_data)
flat_spin_data = [spin_data[i].flatten() for i in range(num_spin_data)]

# %%
fc0_weight = model.state_dict()['fc.0.weight'].cpu().numpy()
fc0_bias = model.state_dict()['fc.0.bias'].cpu().numpy()

# %%
class LatticeIsing_2D():
    def __init__(self, N, J=1, h=0):
        """
        Attributes:
            N: 格子サイズ
            J: 相互作用
            h: 磁場
        """
        self.N=N
        self.J=J
        self.h=h
    
    def neighor_spin_sum(self, state, x, y):

        center_spin = state[y, x]
        right, left, up, down=x+1, x-1, y+1, y-1

        # 周期境界条件
        if right>=self.N:
            right_spin=state[y, 0]
        else:
            right_spin=state[y, right]
            
        if left<0:
            left=self.N-1
            left_spin=state[y, left]
        else:
            left_spin=state[y, left]
            
        if down<0:
            down=self.N-1
            down_spin=state[down, x]
        else:
            down_spin=state[down, x]
    
        if up>=self.N:
            up_spin=state[0, x]
        else:
            up_spin=state[up, x]
            
        neighor_spin_sum=self.J * center_spin * (right_spin+left_spin+up_spin+down_spin)
        return neighor_spin_sum

    # エネルギーを計算
    def energy(self, state):
        energy=0
        for x in range(self.N):
            for y in range(self.N):
                energy -= self.neighor_spin_sum(state, x, y)/2
        energy -= self.h*np.sum(state)
        energy = energy/256
        return energy
    
    # 磁化を計算
    def magnetization(self, state):
        return np.mean(state)

# %%
# イジングモデルのインスタンスを作成
ising_model = LatticeIsing_2D(16)

# %%
output_data_0 = []
output_data_1 = []
output_data_2 = []
mag_data = []
energy_data = []

for i in range(num_spin_data):
    dot_product_0 = output[i][0]
    output_data_0.append(dot_product_0)
    dot_product_1 = output[i][1]
    output_data_1.append(dot_product_1)
    dot_product_2 = output[i][2]
    output_data_2.append(dot_product_2)
    mag = magnetization(flat_spin_data[i])
    mag_data.append(mag)
    energy = ising_model.energy(spin_data[i])
    energy_data.append(energy)

# %%
# データ
x = mag_data
y0 = output_data_0
y1 = output_data_1
y2 = output_data_2

# プロット
plt.figure(figsize=(10, 5))
plt.scatter(x, y0, color='blue', label='a=0')
plt.scatter(x, y1, color='orange', label='a=1')
plt.scatter(x, y2, color='green', label='a=2')
plt.legend()  # 凡例を表示

# plt.title('Output of first layer')
plt.xlabel('magnetization')

# 図をファイルとして保存
plt.savefig(f'image/L{lattice_size}_CNN_Nh{hidden_size}_output.png')
plt.show()

# %% [markdown]
# 内部エネルギーと磁化の相関図

# %%
# データ
x = energy_data
y0 = output_data_0
y1 = output_data_1
y2 = output_data_2

# プロット
plt.figure(figsize=(10, 5))
plt.scatter(x, y0, color='blue', label='a=0')
plt.scatter(x, y1, color='orange', label='a=1')
plt.scatter(x, y2, color='green', label='a=2')
plt.legend()  # 凡例を表示

# plt.title('Output of first layer')
plt.xlabel('internal energy')

# 図をファイルとして保存
plt.savefig(f'image/L{lattice_size}_CNN_Nh{hidden_size}_energy.png')
plt.show()
